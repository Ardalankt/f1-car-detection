# %% [markdown]
# Downloading the dataset to google drive.

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="your_api_key_here")
project = rf.workspace("f1-qxcol").project("formula-one-car-detection-gukm8")
version = project.version(1)
dataset = version.download(
    "yolov8",
    location="/content/f1-dataset"
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/f1-dataset in yolov8:: 100%|██████████| 6350/6350 [00:03<00:00, 1628.00it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !cp -r /content/f1-dataset /content/drive/MyDrive/

# %%
# !ls /content/drive/MyDrive/f1-dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
