# %%
from ultralytics import YOLO
model = YOLO("yolov8x")

# %%
result = model.predict('input/trimmed2.mp4',save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1769) /Users/macbookprom1/Documents/my-projects/f1-team-detection/input/trimmed2.mp4: 384x640 11 persons, 1 car, 2 trucks, 5 traffic lights, 537.6ms
# video 1/1 (frame 2/1769) /Users/macbookprom1/Documents/my-projects/f1-team-detection/input/trimmed2.mp4: 384x640 11 persons, 2 cars, 2 trucks, 5 traffic lights, 472.1ms
# ...
